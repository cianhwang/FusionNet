# %%
from keras.models import Sequential
from keras.layers import ConvLSTM2D, BatchNormalization, Conv2D
import keras
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# # Artificial data generation:
# # Generate movies with 3 to 7 moving squares inside.
# # The squares are of shape 1x1 or 2x2 pixels,
# # which move linearly over time.
# # For convenience we first create movies with bigger width and height (80x80)
# # and at the end we select a 40x40 window.

# def generate_movies(n_samples=1200, n_frames=15):
#     row = 40
#     col = 40
#     noisy_movies = np.zeros((n_samples, n_frames, row, col, 1), dtype=np.float)
#     shifted_movies = np.zeros((n_samples, n_frames, row, col, 1),
#                               dtype=np.float)

#     for i in range(n_samples):
#         # Add 3 to 7 moving squares
#         n = np.random.randint(2, 4)

#         for j in range(n):
#             # Initial position
#             xstart = np.random.randint(10, 30)
#             ystart = np.random.randint(10, 30)
#             # Direction of motion
#             directionx = np.random.randint(0, 3) - 1
#             directiony = np.random.randint(0, 3) - 1

#             # Size of the square
#             w = np.random.randint(1, 3)

#             for t in range(n_frames):
#                 x_shift = xstart + directionx * t
#                 y_shift = ystart + directiony * t
#                 noisy_movies[i, t, x_shift - w: x_shift + w,
#                              y_shift - w: y_shift + w, 0] += 1

#                 # Make it more robust by adding noise.
#                 # The idea is that if during inference,
#                 # the value of the pixel is not exactly one,
#                 # we need to train the network to be robust and still
#                 # consider it as a pixel belonging to a square.
#                 if np.random.randint(0, 2):
#                     noise_f = 0#(-1)**np.random.randint(0, 2)
#                     noisy_movies[i, t,
#                                  x_shift - w - 1: x_shift + w + 1,
#                                  y_shift - w - 1: y_shift + w + 1,
#                                  0] += noise_f * 0.1

#                 # Shift the ground truth by 1
#                 x_shift = xstart + directionx * (t + 1)
#                 y_shift = ystart + directiony * (t + 1)
#                 shifted_movies[i, t, x_shift - w: x_shift + w,
#                                y_shift - w: y_shift + w, 0] += 1

#     # Cut to a 40x40 window
#     noisy_movies = noisy_movies[::, ::, 10:30, 10:30, ::]
#     shifted_movies = shifted_movies[::, ::, 10:30, 10:30, ::]
#     noisy_movies[noisy_movies >= 1] = 1
#     shifted_movies[shifted_movies >= 1] = 1
#     return noisy_movies, shifted_movies

# %%
# # movies, shifted_movies = generate_movies(n_samples=1200)
# a = np.load('mnist_test_seq.npy')
# a = np.swapaxes(a, 0, 1)
# movies = a[:1200, :, ::2, ::2, np.newaxis]/255
# del a

# %%
movies = np.load('video.npy')/255.0
target = np.load('gt.npy')/255.0
print(movies.shape)
print(target.shape)
# Out:
# (200, 20, 64, 64, 3)
# (200, 64, 64, 3)

# %%
seq = Sequential()
seq.add(ConvLSTM2D(filters=32, kernel_size=(5, 5),
                   input_shape=(None, 64, 64, 3),
                   padding='same', return_sequences=True))
seq.add(BatchNormalization())
seq.add(ConvLSTM2D(filters=64, kernel_size=(5, 5),
                   padding='same'))
seq.add(BatchNormalization())
seq.add(Conv2D(filters=3, kernel_size=(5, 5), activation='sigmoid',
                   padding='same'))
seq.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_1 (ConvLSTM2D)  (None, None, 64, 64, 32)  112128
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 64, 64, 32)  128
# _________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)  (None, 64, 64, 64)        614656
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 3)         4803
# =================================================================
# Total params: 731,971
# Trainable params: 731,779
# Non-trainable params: 192
# _________________________________________________________________

# %%
seq.compile(loss='mse', optimizer=keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0))

# %%
seq.fit(movies[:180], target[:180], batch_size=5,
        epochs=20, validation_split=0.1)
# Out:
# Train on 162 samples, validate on 18 samples
# Epoch 1/20
# 162/162 [==============================] - 51s 314ms/step - loss: 0.0227 - val_loss: 0.0491
# Epoch 2/20
# 162/162 [==============================] - 51s 313ms/step - loss: 0.0218 - val_loss: 0.0645
# Epoch 3/20
# 162/162 [==============================] - 51s 313ms/step - loss: 0.0242 - val_loss: 0.1210
# Epoch 4/20
# 162/162 [==============================] - 51s 313ms/step - loss: 0.0218 - val_loss: 0.2121
# Epoch 5/20
# 162/162 [==============================] - 51s 314ms/step - loss: 0.0204 - val_loss: 0.0499
# Epoch 6/20
# 162/162 [==============================] - 51s 313ms/step - loss: 0.0222 - val_loss: 0.0644
# Epoch 7/20
# 162/162 [==============================] - 51s 314ms/step - loss: 0.0188 - val_loss: 0.0685
# Epoch 8/20
# 162/162 [==============================] - 51s 314ms/step - loss: 0.0199 - val_loss: 0.0604
# Epoch 9/20
# 162/162 [==============================] - 51s 314ms/step - loss: 0.0187 - val_loss: 0.1479
# Epoch 10/20
# 162/162 [==============================] - 51s 313ms/step - loss: 0.0197 - val_loss: 0.3442
# Epoch 11/20
# 162/162 [==============================] - 51s 316ms/step - loss: 0.0181 - val_loss: 0.0753
# Epoch 12/20
#  70/162 [===========>..................] - ETA: 27s - loss: 0.0171
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-ac8fcd59046b> in <module>
#       1 seq.fit(movies[:180], target[:180], batch_size=5,
# ----> 2         epochs=20, validation_split=0.1)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
a = seq.predict(movies[0:10])

# %%
for i in range(10):
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(121)
    plt.imshow(target[i])
    ax = fig.add_subplot(122)
    plt.imshow(a[i])

# %%
# plt.imshow(movies[1000, 8, :, :, 0])

# %%
# plt.imshow(a[0, :, :, 0])

# %%
# for i in range(5):
#     fig = plt.figure(figsize=(10, 5))
#     ax = fig.add_subplot(151)
#     plt.imshow(movies[1000+i, 7, :, :, 0])
#     ax = fig.add_subplot(152)
#     plt.imshow(movies[1000+i, 8, :, :, 0])
#     ax = fig.add_subplot(153)
#     plt.imshow(movies[1000+i, 9, :, :, 0])
#     ax = fig.add_subplot(154)
#     plt.imshow(movies[1000+i, 10, :, :, 0])
#     ax = fig.add_subplot(155)
#     plt.imshow(a[i, :, :, 0])
